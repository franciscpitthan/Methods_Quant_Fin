# %% [markdown]
# # INTRODUCTION
#
# - **Randomness in Financial Markets**: Financial markets exhibit significant randomness, making it crucial to incorporate probabilistic models.
# - **Jensen’s Inequality**: Shows that the order of expectation and payoff calculations matters, emphasizing the need to model randomness accurately.
# - **Continuous Time Models**: Provide a more realistic and robust framework for understanding asset price movements and derivative pricing.
# - **Normal Distribution**: Central to financial modeling due to its natural occurrence and mathematical properties, facilitating the modeling of asset returns.
#
# Three main types of analysis used in finance:
#
# 1. Fundamental Analysis: Deep study of company fundamentals (e.g., balance sheets, management). It is challenging due to hidden information and the market's potential irrationality.
# 2. Technical Analysis: Focus on stock price history and patterns (e.g. 'head and shoulders'). Most academic evidence suggests it is not effective.
# 3. Quantitative Analysis: This approach treats financial quantities as random variables and uses statistical models to understand and predict their behavior.  (e.g. Black-Scholes-Merton). It has been the most successful method in modern finance, forming the basis for portfolio theory, derivatives pricing, and risk management.
#
# **Importance of Randomness:** Randomness is crucial in financial modeling because it captures the inherent uncertainty in asset price movements. Jensen's inequality illustrates why incorporating randomness leads to more accurate and realistic option pricing.

# %%
#Example of price randomness following binomial distribution
import numpy as np
import matplotlib.pyplot as plt

# Parameters
initial_price = 100
n_steps = 20  # Number of time steps
n_simulations = 3  # Number of simulations
increase_factor = 1.1
decrease_factor = 0.9
seed = 42

# Set random seed for reproducibility
np.random.seed(seed)

# Simulation function
def simulate_stock_price(initial_price, n_steps, increase_factor, decrease_factor):
    prices = [initial_price]
    for _ in range(n_steps):
        if np.random.rand() < 0.5:
            new_price = prices[-1] * increase_factor
        else:
            new_price = prices[-1] * decrease_factor
        prices.append(new_price)
    return prices

# Run simulations
all_simulations = [simulate_stock_price(initial_price, n_steps, increase_factor, decrease_factor) for _ in range(n_simulations)]

# Time labels starting from 2000
years = np.arange(2000, 2000 + n_steps + 1)

# Plot results
plt.figure(figsize=(14, 8))
for simulation in all_simulations:
    plt.plot(years, simulation, lw=2)
plt.title('Stock Price Simulations following Binomial Distribution', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Stock Price', fontsize=14)
plt.grid(True)
plt.axhline(y=initial_price, color='r', linestyle='--', label='Initial Price')
plt.xticks(years, [str(year) for year in years])  
plt.legend()
plt.show()

# %% [markdown]
# **Modeling Returns:** Rather than modeling absolute prices, financial modeling focuses on returns, which are the relative changes in price. This approach is applicable to various asset classes, including equities, currencies, commodities, and indices, and helps in comparing investments of different sizes. The return is given by the time diference in prices $P$ accounting for accumulated cashflows $D$.
#
# $$ R = \frac{P_{\text{t+1}} - P_{\text{t}} + D}{P_{\text{t}}} $$

# %%
#Plot S&P500 returns

#Possible to use yfinance to obtain data through Yahoo Finance (needs to install using 'pip install yfinance' in your prompt)
#!pip install yfinance #Execute in case not installed yet

import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Download needed data, here Belgium's BEL 20 (^BFX)
# Could be changed for other, like S&P 500 data (ticker ^GSPC)
ticker = "^BFX"
data = yf.download(ticker, start="2002-01-01", end="2024-01-01")

# Calculate daily returns
data['Daily Return'] = data['Adj Close'].pct_change()

# Calculate cumulative returns
data['Cumulative Return'] = (1 + data['Daily Return']).cumprod() - 1

# Plot the cumulative returns
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Cumulative Return'], label='Cumulative Return')
plt.title('BEL 20 Cumulative Return (2004-2024)')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.legend()
plt.grid(True)
plt.show()


# Plot returns
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Daily Return'], label='Daily Return')
plt.title('BEL 20 Daily Returns (2004-2024)')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
